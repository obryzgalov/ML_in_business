# %% [markdown]
# ### Домашнее задание

# %% [markdown]
# #### 1. Если мы рассчитали 95% доверительный интервал для среднего значения, то какие из следующих утверждений являются верными?
#
# Выберите несколько вариантов и попытайтесь объяснить свой выбор:
#
# 1) Если многократно повторять эксперимент, то 95 % выборочных средних значений будут принадлежать рассчитанному нами доверительному интервалу.
#
# 2) Мы можем быть на 95% уверены, что среднее значение в генеральной совокупности принадлежит рассчитанному доверительному интервалу.
#
# 3) Если многократно повторять эксперимент, для каждой выборки рассчитывать свой доверительный интервал, то в 95 % случаев истинное среднее будет находиться внутри доверительного интервала.
#
# 4) Среднее значение в генеральной совокупности точно превышает нижнюю границу 95% доверительного интервала.
#
# 5) Среднее значение в генеральной совокупности точно принадлежит рассчитанному доверительному интервалу.

# %% [markdown]
# Правильными уутерждениями являются:
#
# 1) Если многократно пповторять эксперимент, то 95 % выборочных средних значений будут принадлежать рассчитанному нами доверительному интервалу.
#
# 3) Если многократно повторять эксперимент, для каждой выборки рассчитывать свой доверительный интервал, то в 95 % случаев истинное среднее будет находиться внутри доверительного интервала.
#
# Объяснние:
#
# 1) верно, так как 95% дверрительный интервал подразумевает, что при многократом повторении экпперимента 95% выборочых статистик (в данном случае средних) будут попадать в рассчитанный интервал.
#
# 3) верно по той же причине - 95% увереннность означает, что в 95% слччаев истинное значение будет внутри доверительного интервала.
#
# Остальные утверждения неверны, так как 95% довертельный интервал не гарантирует, что истинное значение обязтельноо попадет в него. Это лишь вероятность.

# %% [markdown]
# #### 2. Если мы увеличиваем объем выборки в два раза (при условии, что показатель стандартного отклонения остается неизменным), то 95% доверительный интервал
#
# Выберите один вариант из списка:
#
#     1) стал более узким
#     2) возможны оба варианта
#     3) стал более широким

# %% [markdown]
# Правильный ответ:
#
# 1) стал более узким
#
# Объяснение:
#
# При увеличении объема выборки в два раза, стандартная ошибка среднего уменьшается (так как знаменатель увеличивается).
#
# А поскольку границы 95% доверительного интервала зависят от стандартной ошибки среднего, то при ее уменьшении доверительный интервал становится более узким.
#
# Таким образом, при прочих равных условиях, увеличение объема выбори ведет к сужению доверительогоо интервала для среднего.

# %% [markdown]
# #### 3. В центре 95% доверительного интервала, рассчитанного по выборочным значениям, находится:
#
# Выберите один вариант из списка
#
#     1) Значение стандартной ошибки среднего
#     2) Выборочное среднее значение
#     3) Среднее значение генеральной совокупности

# %% [markdown]
# Правильный ответ:
#
# 2) Выборочное среднее значение
#
# Объяснение:
#
# 95% доверительный интервал для среднего рассчитывается по формуле:
#
# (выборочное среднее)) ± (коэффициент) × (стандартная ошибка среднего)
#
# То есть центром интервала является выборочное среднее значение. Стандартная ошибка среднего и истинное среднее значение генеральной совокуности находятся не посередине, а определяют границы интервала.
#
# Поэтому верный ответ - выборочное среднее значение.

# %% [markdown]
# #### 4. Часто на практике нулевая гипотеза отклоняется, и различия считаются статистически достоверными, если p < 0,05. Однако часто в статистике используется более жесткий критерий достоверности различий, например, при условии, что p < 0,01. Значение p-уровня значимости, которое выбирается, в качестве порога обозначается буквой α (альфа). Например, если исследователь решил, что α = 0,05, то и нулевая гипотеза будет отклоняться при условии, что p < 0,05.
#
# #### Если в определенной ситуации весьма рискованно отклонить нулевую гипотезу, когда она на самом деле верна, то лучше использовать показатель α равный
#
# Выберите один вариант из списка
#
#     1) 0,1
#     2) 0,001
#     3) 0,05
#     4) 0,5
#
# Правильный ответ:
#
# 2) 0,001
#
# Объяснение:
#
# Если в определенной ситуации весьма рискованно отклонить нулевую гипотезу, когда она на самом деле верна, то нужно использовать меньшее значение α (более жесткий критерий).
#
# Чем меньше α, тем меньше вероятность ошибочно отклонить верную нулевую гипотезу (ошибка 1-го рода).

# %% [markdown]
# #### 5. Данные некоторого исследования сообщают нам, что средний рост детей в 14 лет составляет 166 сантиметров. Однако это лишь выборочная оценка, и исследователи рассчитали 95% доверительный интервал, который составил [160, 172]. Укажите верные утверждения:
#
# Выберите несколько вариантов и попытайтесь объяснить свой выбор:
#
#     1) У нас достаточно оснований отклонить нулевую гипотезу, что среднее в генеральной совокупности равняется 173
#     2) Вероятность того, что истинное среднее значение больше 172, составляет 0,01
#     3) У нас достаточно оснований отклонить нулевую гипотезу, что среднее в генеральной совокупности равняется 158.
#     4) Доверительный интервал не может иметь такие границы, т. к. выборочное стандартное отклонение равняется 10, следовательно доверительный интервал должен быть значительно шире.

# %% [markdown]
# В данном случае верны утерждения 1 и 3.
#
# Объяснение:
#
# 1) Верно. Так как 173 находится за пределами доверительного интервала [160, 172], мы можем отклонить нулевую гипотезу о том, что среднее в генеральной совокупности равно 173.
#
# 2) Неверно. 0,01 - это уровень значимости, а не вероятность. Мы не можем определить точную вероятность.
#
# 3) Верно, по той же причине, что и пункт 1. 158 находится за пределами доверительного интервала, значит мы можем отклонить гипотезу о том, что среднее равно 158.
#
# 4) Неверно. Ширина доверительного интервала звисит не только от стандартного отклонения, но и от размера выборки. Мы не знаем размер выборки, поэтому не можем судить о ширине интервала.

# %% [markdown]
# #### 6. Предположим, нулевой гипотезой вашего исследования являлось предположение, что конверсия в генеральной совокупности равняется 0.4. Вы получили p = 0,12 и не смогли отклонить нулевую гипотезу. Однако позже выяснилось, что конверсия в генеральной совокупности действиетльно равна 0.4. Как можно оценить результаты?
#
#
# Какой вариант корректный по вашему мнению и почему?
#
#     1) Вы не совершали ни ошибку первого рода, ни ошибку второго рода.
#     2) Вы совершили ошибку первого рода
#     3) Вы совершили ошибку второго рода

# %% [markdown]
# В данном случае корректным ответом является вариант 1 - мы не совершали ни ошибки первого, ни ошибки второго рода.
#
# Пояснение:
#
# Ошибка первого рода - это когда мы отвергаем верную нулевую гипотезу.
#
# Ошибка второго рода - когда мы принимаем неверную нулевую гипотезу.
#
# В нашем случае:
#
# 1) Мы не отвергли нулевую гипотезу о том, что конверсия = 0.4 (p = 0.12 > 0.05)
#
# 2) И выяснилось, что нулеева гииптеза верна - конверсия действительно = 0.4
#
# То есть мы не совершили ни ошибки первого рода (не отвергли верную гипотезу), ни ошибки второго рода (не приняли неверную гипотезу).
#
# Поэтому вариант 1 является верным. Мы поступили корректно, не отвергнув истиннуюю нулевую гипотезу.
